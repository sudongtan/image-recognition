# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    new_x = []
    for image in x:
        #min_image = np.min(image)
        #max_image = np.max(image)
        min_image = 0
        max_image = 255
        new_image = (image - min_image)/(max_image - min_image)
        new_x.append(new_image)
    return np.array(new_x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lb = LabelBinarizer()
    lb.fit(range(10))    
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None,)+image_shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None,n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    conv_weights = tf.Variable(tf.truncated_normal(
                    [*conv_ksize, x_tensor.get_shape().as_list()[-1], conv_num_outputs], 0, 0.1))
    
    conv_biases = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv = tf.nn.conv2d(x_tensor, conv_weights, [1, *conv_strides, 1], padding="SAME")
    bias = tf.nn.bias_add(conv, conv_biases)
    relu = tf.nn.relu(bias)
    max_pool = tf.nn.max_pool(relu, [1, *pool_ksize, 1], [1, *pool_strides, 1], padding="SAME")
       
    return max_pool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    dim1 = shape[0]
    dim2 = shape[1]
    dim3 = shape[2]
    dim4 = shape[3]
    
    return tf.reshape(x_tensor, [-1, dim2*dim3*dim4])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    
    weights = tf.Variable(tf.truncated_normal([shape[-1], num_outputs], 0, 0.1))
    biases = tf.Variable(tf.zeros([num_outputs]))
    return tf.nn.relu(tf.matmul(x_tensor, weights) + biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    
    weights = tf.Variable(tf.truncated_normal([shape[-1], num_outputs], 0, 0.1))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.matmul(x_tensor, weights) + biases


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    conv_ksize = (5, 5)
    conv_strides = (1, 1)
    pool_ksize = (4, 4)
    pool_strides = (1, 1)
    model = conv2d_maxpool(x, 2 * 16, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #model = conv2d_maxpool(x, 2 * 32, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #model = conv2d_maxpool(x, 2 * 64, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #model = conv2d_maxpool(x, 2 * 64, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #model = tf.nn.dropout(model, keep_prob)

    model = tf.nn.dropout(model, keep_prob)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model = flatten(model)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    model = fully_conn(model, 500)

    model = tf.nn.dropout(model, keep_prob)
    #model = fully_conn(model, 512)
    #model = fully_conn(model, 128)
    #model = tf.nn.dropout(model, keep_prob)    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    model = output(model, 10) 
    #model = tf.nn.softmax(model)
        
    # TODO: return output
    return model


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x:feature_batch, 
                                        y:label_batch, 
                                        keep_prob:1.0})
    valid_acc = session.run(accuracy, feed_dict={x: valid_features,
                                              y: valid_labels,
                                              keep_prob: 1.0})
    print("loss: ", loss)
    print("validation accuracy: ", valid_acc)

# %%
len(valid_features)
# Out:
# 5000

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 500
keep_probability = 0.2

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.30163
# validation accuracy:  0.1028
# Epoch  2, CIFAR-10 Batch 1:  loss:  2.30264
# validation accuracy:  0.1062
# Epoch  3, CIFAR-10 Batch 1:  loss:  2.29185
# validation accuracy:  0.133
# Epoch  4, CIFAR-10 Batch 1:  loss:  2.28192
# validation accuracy:  0.144
# Epoch  5, CIFAR-10 Batch 1:  loss:  2.24258
# validation accuracy:  0.1742
# Epoch  6, CIFAR-10 Batch 1:  loss:  2.24866
# validation accuracy:  0.1588
# Epoch  7, CIFAR-10 Batch 1:  loss:  2.20959
# validation accuracy:  0.2196
# Epoch  8, CIFAR-10 Batch 1:  loss:  2.19763
# validation accuracy:  0.2178
# Epoch  9, CIFAR-10 Batch 1:  loss:  2.15225
# validation accuracy:  0.2378
# Epoch 10, CIFAR-10 Batch 1:  loss:  2.134
# validation accuracy:  0.2536
# Epoch 11, CIFAR-10 Batch 1:  loss:  2.08553
# validation accuracy:  0.2808
# Epoch 12, CIFAR-10 Batch 1:  loss:  2.04315
# validation accuracy:  0.295
# Epoch 13, CIFAR-10 Batch 1:  loss:  2.01236
# validation accuracy:  0.3088
# Epoch 14, CIFAR-10 Batch 1:  loss:  1.92293
# validation accuracy:  0.3426
# Epoch 15, CIFAR-10 Batch 1:  loss:  1.92207
# validation accuracy:  0.3418
# Epoch 16, CIFAR-10 Batch 1:  loss:  1.87539
# validation accuracy:  0.356
# Epoch 17, CIFAR-10 Batch 1:  loss:  1.84681
# validation accuracy:  0.3462
# Epoch 18, CIFAR-10 Batch 1:  loss:  1.81708
# validation accuracy:  0.362
# Epoch 19, CIFAR-10 Batch 1:  loss:  1.78716
# validation accuracy:  0.3676
# Epoch 20, CIFAR-10 Batch 1:  loss:  1.77418
# validation accuracy:  0.3718
# Epoch 21, CIFAR-10 Batch 1:  loss:  1.75483
# validation accuracy:  0.3638
# Epoch 22, CIFAR-10 Batch 1:  loss:  1.7577
# validation accuracy:  0.3806
# Epoch 23, CIFAR-10 Batch 1:  loss:  1.71792
# validation accuracy:  0.3948
# Epoch 24, CIFAR-10 Batch 1:  loss:  1.71503
# validation accuracy:  0.4084
# Epoch 25, CIFAR-10 Batch 1:  loss:  1.68508
# validation accuracy:  0.4112
# Epoch 26, CIFAR-10 Batch 1:  loss:  1.65944
# validation accuracy:  0.412
# Epoch 27, CIFAR-10 Batch 1:  loss:  1.6535
# validation accuracy:  0.4242
# Epoch 28, CIFAR-10 Batch 1:  loss:  1.64784
# validation accuracy:  0.4242
# Epoch 29, CIFAR-10 Batch 1:  loss:  1.62931
# validation accuracy:  0.4276
# Epoch 30, CIFAR-10 Batch 1:  loss:  1.61908
# validation accuracy:  0.4268
# Epoch 31, CIFAR-10 Batch 1:  loss:  1.58208
# validation accuracy:  0.434
# Epoch 32, CIFAR-10 Batch 1:  loss:  1.55731
# validation accuracy:  0.4484
# Epoch 33, CIFAR-10 Batch 1:  loss:  1.54001
# validation accuracy:  0.4484
# Epoch 34, CIFAR-10 Batch 1:  loss:  1.52748
# validation accuracy:  0.4432
# Epoch 35, CIFAR-10 Batch 1:  loss:  1.51747
# validation accuracy:  0.4604
# Epoch 36, CIFAR-10 Batch 1:  loss:  1.50484
# validation accuracy:  0.4592
# Epoch 37, CIFAR-10 Batch 1:  loss:  1.49014
# validation accuracy:  0.4702
# Epoch 38, CIFAR-10 Batch 1:  loss:  1.47841
# validation accuracy:  0.47
# Epoch 39, CIFAR-10 Batch 1:  loss:  1.46359
# validation accuracy:  0.477
# Epoch 40, CIFAR-10 Batch 1:  loss:  1.44824
# validation accuracy:  0.4738
# Epoch 41, CIFAR-10 Batch 1:  loss:  1.45912
# validation accuracy:  0.4688
# Epoch 42, CIFAR-10 Batch 1:  loss:  1.43074
# validation accuracy:  0.4796
# Epoch 43, CIFAR-10 Batch 1:  loss:  1.4012
# validation accuracy:  0.4772
# Epoch 44, CIFAR-10 Batch 1:  loss:  1.40197
# validation accuracy:  0.4802
# Epoch 45, CIFAR-10 Batch 1:  loss:  1.3793
# validation accuracy:  0.482
# Epoch 46, CIFAR-10 Batch 1:  loss:  1.38179
# validation accuracy:  0.4832
# Epoch 47, CIFAR-10 Batch 1:  loss:  1.34625
# validation accuracy:  0.494
# Epoch 48, CIFAR-10 Batch 1:  loss:  1.34144
# validation accuracy:  0.4938
# Epoch 49, CIFAR-10 Batch 1:  loss:  1.31753
# validation accuracy:  0.503
# Epoch 50, CIFAR-10 Batch 1:  loss:  1.33166
# validation accuracy:  0.503
# Epoch 51, CIFAR-10 Batch 1:  loss:  1.30373
# validation accuracy:  0.5092
# Epoch 52, CIFAR-10 Batch 1:  loss:  1.2745
# validation accuracy:  0.5064
# Epoch 53, CIFAR-10 Batch 1:  loss:  1.28571
# validation accuracy:  0.5102
# Epoch 54, CIFAR-10 Batch 1:  loss:  1.27717
# validation accuracy:  0.5144
# Epoch 55, CIFAR-10 Batch 1:  loss:  1.25685
# validation accuracy:  0.5226
# Epoch 56, CIFAR-10 Batch 1:  loss:  1.24945
# validation accuracy:  0.5204
# Epoch 57, CIFAR-10 Batch 1:  loss:  1.22342
# validation accuracy:  0.5262
# Epoch 58, CIFAR-10 Batch 1:  loss:  1.21646
# validation accuracy:  0.5248
# Epoch 59, CIFAR-10 Batch 1:  loss:  1.22704
# validation accuracy:  0.5224
# Epoch 60, CIFAR-10 Batch 1:  loss:  1.19465
# validation accuracy:  0.533
# Epoch 61, CIFAR-10 Batch 1:  loss:  1.20734
# validation accuracy:  0.5262
# Epoch 62, CIFAR-10 Batch 1:  loss:  1.20019
# validation accuracy:  0.529
# Epoch 63, CIFAR-10 Batch 1:  loss:  1.18335
# validation accuracy:  0.5306
# Epoch 64, CIFAR-10 Batch 1:  loss:  1.17967
# validation accuracy:  0.5362
# Epoch 65, CIFAR-10 Batch 1:  loss:  1.16399
# validation accuracy:  0.529
# Epoch 66, CIFAR-10 Batch 1:  loss:  1.14698
# validation accuracy:  0.5416
# Epoch 67, CIFAR-10 Batch 1:  loss:  1.16523
# validation accuracy:  0.5346
# Epoch 68, CIFAR-10 Batch 1:  loss:  1.1513
# validation accuracy:  0.5442
# Epoch 69, CIFAR-10 Batch 1:  loss:  1.1416
# validation accuracy:  0.547
# Epoch 70, CIFAR-10 Batch 1:  loss:  1.12764
# validation accuracy:  0.54
# Epoch 71, CIFAR-10 Batch 1:  loss:  1.11016
# validation accuracy:  0.5558
# Epoch 72, CIFAR-10 Batch 1:  loss:  1.11732
# validation accuracy:  0.5482
# Epoch 73, CIFAR-10 Batch 1:  loss:  1.10929
# validation accuracy:  0.5504
# Epoch 74, CIFAR-10 Batch 1:  loss:  1.08227
# validation accuracy:  0.5568
# Epoch 75, CIFAR-10 Batch 1:  loss:  1.07601
# validation accuracy:  0.5522
# Epoch 76, CIFAR-10 Batch 1:  loss:  1.07025
# validation accuracy:  0.5502
# Epoch 77, CIFAR-10 Batch 1:  loss:  1.05725
# validation accuracy:  0.5482
# Epoch 78, CIFAR-10 Batch 1:  loss:  1.05677
# validation accuracy:  0.5528
# Epoch 79, CIFAR-10 Batch 1:  loss:  1.0469
# validation accuracy:  0.559
# Epoch 80, CIFAR-10 Batch 1:  loss:  1.03818
# validation accuracy:  0.5578
# Epoch 81, CIFAR-10 Batch 1:  loss:  1.05511
# validation accuracy:  0.5598
# Epoch 82, CIFAR-10 Batch 1:  loss:  1.03891
# validation accuracy:  0.5498
# Epoch 83, CIFAR-10 Batch 1:  loss:  1.01694
# validation accuracy:  0.5626
# Epoch 84, CIFAR-10 Batch 1:  loss:  0.996779
# validation accuracy:  0.5636
# Epoch 85, CIFAR-10 Batch 1:  loss:  1.00862
# validation accuracy:  0.5638
# Epoch 86, CIFAR-10 Batch 1:  loss:  1.00117
# validation accuracy:  0.5578
# Epoch 87, CIFAR-10 Batch 1:  loss:  0.989607
# validation accuracy:  0.5638
# Epoch 88, CIFAR-10 Batch 1:  loss:  0.981417
# validation accuracy:  0.5672
# Epoch 89, CIFAR-10 Batch 1:  loss:  0.979915
# validation accuracy:  0.5678
# Epoch 90, CIFAR-10 Batch 1:  loss:  0.996771
# validation accuracy:  0.5648
# Epoch 91, CIFAR-10 Batch 1:  loss:  0.979948
# validation accuracy:  0.5678
# Epoch 92, CIFAR-10 Batch 1:  loss:  0.977552
# validation accuracy:  0.566
# Epoch 93, CIFAR-10 Batch 1:  loss:  0.951753
# validation accuracy:  0.5708
# Epoch 94, CIFAR-10 Batch 1:  loss:  0.960436
# validation accuracy:  0.56
# Epoch 95, CIFAR-10 Batch 1:  loss:  0.936372
# validation accuracy:  0.5718
# Epoch 96, CIFAR-10 Batch 1:  loss:  0.927903
# validation accuracy:  0.5734
# Epoch 97, CIFAR-10 Batch 1:  loss:  0.923188
# validation accuracy:  0.5746
# Epoch 98, CIFAR-10 Batch 1:  loss:  0.932868
# validation accuracy:  0.5774
# Epoch 99, CIFAR-10 Batch 1:  loss:  0.925867
# validation accuracy:  0.57
# Epoch 100, CIFAR-10 Batch 1:  loss:  0.91959
# validation accuracy:  0.573

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss:  2.29813
# validation accuracy:  0.1116
# Epoch  1, CIFAR-10 Batch 2:  loss:  2.29937
# validation accuracy:  0.1406
# Epoch  1, CIFAR-10 Batch 3:  loss:  2.286
# validation accuracy:  0.1474
# Epoch  1, CIFAR-10 Batch 4:  loss:  2.24581
# validation accuracy:  0.228
# Epoch  1, CIFAR-10 Batch 5:  loss:  2.17252
# validation accuracy:  0.2694
# Epoch  2, CIFAR-10 Batch 1:  loss:  2.15775
# validation accuracy:  0.2816
# Epoch  2, CIFAR-10 Batch 2:  loss:  2.09409
# validation accuracy:  0.3096
# Epoch  2, CIFAR-10 Batch 3:  loss:  1.99803
# validation accuracy:  0.317
# Epoch  2, CIFAR-10 Batch 4:  loss:  1.97146
# validation accuracy:  0.331
# Epoch  2, CIFAR-10 Batch 5:  loss:  1.9553
# validation accuracy:  0.3494
# Epoch  3, CIFAR-10 Batch 1:  loss:  1.9022
# validation accuracy:  0.3644
# Epoch  3, CIFAR-10 Batch 2:  loss:  1.88056
# validation accuracy:  0.3586
# Epoch  3, CIFAR-10 Batch 3:  loss:  1.77547
# validation accuracy:  0.3784
# Epoch  3, CIFAR-10 Batch 4:  loss:  1.7853
# validation accuracy:  0.3798
# Epoch  3, CIFAR-10 Batch 5:  loss:  1.80265
# validation accuracy:  0.3852
# Epoch  4, CIFAR-10 Batch 1:  loss:  1.76951
# validation accuracy:  0.4084
# Epoch  4, CIFAR-10 Batch 2:  loss:  1.79884
# validation accuracy:  0.3848
# Epoch  4, CIFAR-10 Batch 3:  loss:  1.67797
# validation accuracy:  0.415
# Epoch  4, CIFAR-10 Batch 4:  loss:  1.66659
# validation accuracy:  0.4186
# Epoch  4, CIFAR-10 Batch 5:  loss:  1.73583
# validation accuracy:  0.4082
# Epoch  5, CIFAR-10 Batch 1:  loss:  1.68302
# validation accuracy:  0.426
# Epoch  5, CIFAR-10 Batch 2:  loss:  1.69819
# validation accuracy:  0.4028
# Epoch  5, CIFAR-10 Batch 3:  loss:  1.64372
# validation accuracy:  0.4104
# Epoch  5, CIFAR-10 Batch 4:  loss:  1.59701
# validation accuracy:  0.4294
# Epoch  5, CIFAR-10 Batch 5:  loss:  1.64887
# validation accuracy:  0.4288
# Epoch  6, CIFAR-10 Batch 1:  loss:  1.62351
# validation accuracy:  0.424
# Epoch  6, CIFAR-10 Batch 2:  loss:  1.64509
# validation accuracy:  0.4318
# Epoch  6, CIFAR-10 Batch 3:  loss:  1.52727
# validation accuracy:  0.4462
# Epoch  6, CIFAR-10 Batch 4:  loss:  1.54038
# validation accuracy:  0.4444
# Epoch  6, CIFAR-10 Batch 5:  loss:  1.61201
# validation accuracy:  0.4484
# Epoch  7, CIFAR-10 Batch 1:  loss:  1.5651
# validation accuracy:  0.4582
# Epoch  7, CIFAR-10 Batch 2:  loss:  1.56916
# validation accuracy:  0.449
# Epoch  7, CIFAR-10 Batch 3:  loss:  1.5005
# validation accuracy:  0.4538
# Epoch  7, CIFAR-10 Batch 4:  loss:  1.47237
# validation accuracy:  0.4664
# Epoch  7, CIFAR-10 Batch 5:  loss:  1.55401
# validation accuracy:  0.476
# Epoch  8, CIFAR-10 Batch 1:  loss:  1.52029
# validation accuracy:  0.477
# Epoch  8, CIFAR-10 Batch 2:  loss:  1.53159
# validation accuracy:  0.4674
# Epoch  8, CIFAR-10 Batch 3:  loss:  1.44198
# validation accuracy:  0.473
# Epoch  8, CIFAR-10 Batch 4:  loss:  1.43133
# validation accuracy:  0.4818
# Epoch  8, CIFAR-10 Batch 5:  loss:  1.51197
# validation accuracy:  0.4812
# Epoch  9, CIFAR-10 Batch 1:  loss:  1.48302
# validation accuracy:  0.4934
# Epoch  9, CIFAR-10 Batch 2:  loss:  1.48413
# validation accuracy:  0.4912
# Epoch  9, CIFAR-10 Batch 3:  loss:  1.3796
# validation accuracy:  0.499
# Epoch  9, CIFAR-10 Batch 4:  loss:  1.39711
# validation accuracy:  0.4956
# Epoch  9, CIFAR-10 Batch 5:  loss:  1.45738
# validation accuracy:  0.5
# Epoch 10, CIFAR-10 Batch 1:  loss:  1.44882
# validation accuracy:  0.498
# Epoch 10, CIFAR-10 Batch 2:  loss:  1.4449
# validation accuracy:  0.4894
# Epoch 10, CIFAR-10 Batch 3:  loss:  1.34801
# validation accuracy:  0.5038
# Epoch 10, CIFAR-10 Batch 4:  loss:  1.35964
# validation accuracy:  0.5086
# Epoch 10, CIFAR-10 Batch 5:  loss:  1.43102
# validation accuracy:  0.5214
# Epoch 11, CIFAR-10 Batch 1:  loss:  1.40173
# validation accuracy:  0.5106
# Epoch 11, CIFAR-10 Batch 2:  loss:  1.45085
# validation accuracy:  0.4896
# Epoch 11, CIFAR-10 Batch 3:  loss:  1.36149
# validation accuracy:  0.51
# Epoch 11, CIFAR-10 Batch 4:  loss:  1.3283
# validation accuracy:  0.5222
# Epoch 11, CIFAR-10 Batch 5:  loss:  1.41901
# validation accuracy:  0.518
# Epoch 12, CIFAR-10 Batch 1:  loss:  1.39973
# validation accuracy:  0.5168
# Epoch 12, CIFAR-10 Batch 2:  loss:  1.40929
# validation accuracy:  0.5096
# Epoch 12, CIFAR-10 Batch 3:  loss:  1.3113
# validation accuracy:  0.524
# Epoch 12, CIFAR-10 Batch 4:  loss:  1.29393
# validation accuracy:  0.534
# Epoch 12, CIFAR-10 Batch 5:  loss:  1.35231
# validation accuracy:  0.5296
# Epoch 13, CIFAR-10 Batch 1:  loss:  1.33848
# validation accuracy:  0.5368
# Epoch 13, CIFAR-10 Batch 2:  loss:  1.36269
# validation accuracy:  0.5236
# Epoch 13, CIFAR-10 Batch 3:  loss:  1.2897
# validation accuracy:  0.5286
# Epoch 13, CIFAR-10 Batch 4:  loss:  1.2608
# validation accuracy:  0.5404
# Epoch 13, CIFAR-10 Batch 5:  loss:  1.35101
# validation accuracy:  0.534
# Epoch 14, CIFAR-10 Batch 1:  loss:  1.33766
# validation accuracy:  0.5398
# Epoch 14, CIFAR-10 Batch 2:  loss:  1.33561
# validation accuracy:  0.533
# Epoch 14, CIFAR-10 Batch 3:  loss:  1.26844
# validation accuracy:  0.5368
# Epoch 14, CIFAR-10 Batch 4:  loss:  1.26188
# validation accuracy:  0.5282
# Epoch 14, CIFAR-10 Batch 5:  loss:  1.28728
# validation accuracy:  0.546
# Epoch 15, CIFAR-10 Batch 1:  loss:  1.29909
# validation accuracy:  0.5482
# Epoch 15, CIFAR-10 Batch 2:  loss:  1.3585
# validation accuracy:  0.508
# Epoch 15, CIFAR-10 Batch 3:  loss:  1.2167
# validation accuracy:  0.5428
# Epoch 15, CIFAR-10 Batch 4:  loss:  1.22957
# validation accuracy:  0.5498
# Epoch 15, CIFAR-10 Batch 5:  loss:  1.28551
# validation accuracy:  0.5356
# Epoch 16, CIFAR-10 Batch 1:  loss:  1.29803
# validation accuracy:  0.5432
# Epoch 16, CIFAR-10 Batch 2:  loss:  1.28748
# validation accuracy:  0.5432
# Epoch 16, CIFAR-10 Batch 3:  loss:  1.20379
# validation accuracy:  0.5514
# Epoch 16, CIFAR-10 Batch 4:  loss:  1.19439
# validation accuracy:  0.5588
# Epoch 16, CIFAR-10 Batch 5:  loss:  1.25264
# validation accuracy:  0.5566
# Epoch 17, CIFAR-10 Batch 1:  loss:  1.28018
# validation accuracy:  0.555
# Epoch 17, CIFAR-10 Batch 2:  loss:  1.25895
# validation accuracy:  0.5542
# Epoch 17, CIFAR-10 Batch 3:  loss:  1.18561
# validation accuracy:  0.5584
# Epoch 17, CIFAR-10 Batch 4:  loss:  1.16504
# validation accuracy:  0.5566
# Epoch 17, CIFAR-10 Batch 5:  loss:  1.23222
# validation accuracy:  0.5634
# Epoch 18, CIFAR-10 Batch 1:  loss:  1.22199
# validation accuracy:  0.5678
# Epoch 18, CIFAR-10 Batch 2:  loss:  1.22931
# validation accuracy:  0.56
# Epoch 18, CIFAR-10 Batch 3:  loss:  1.16426
# validation accuracy:  0.5712
# Epoch 18, CIFAR-10 Batch 4:  loss:  1.15174
# validation accuracy:  0.5594
# Epoch 18, CIFAR-10 Batch 5:  loss:  1.19574
# validation accuracy:  0.579
# Epoch 19, CIFAR-10 Batch 1:  loss:  1.18835
# validation accuracy:  0.5714
# Epoch 19, CIFAR-10 Batch 2:  loss:  1.21828
# validation accuracy:  0.561
# Epoch 19, CIFAR-10 Batch 3:  loss:  1.16085
# validation accuracy:  0.5656
# Epoch 19, CIFAR-10 Batch 4:  loss:  1.13229
# validation accuracy:  0.58
# Epoch 19, CIFAR-10 Batch 5:  loss:  1.18582
# validation accuracy:  0.5694
# Epoch 20, CIFAR-10 Batch 1:  loss:  1.18932
# validation accuracy:  0.5784
# Epoch 20, CIFAR-10 Batch 2:  loss:  1.19984
# validation accuracy:  0.5704
# Epoch 20, CIFAR-10 Batch 3:  loss:  1.12515
# validation accuracy:  0.5814
# Epoch 20, CIFAR-10 Batch 4:  loss:  1.14781
# validation accuracy:  0.5666
# Epoch 20, CIFAR-10 Batch 5:  loss:  1.18237
# validation accuracy:  0.5734
# Epoch 21, CIFAR-10 Batch 1:  loss:  1.16333
# validation accuracy:  0.5846
# Epoch 21, CIFAR-10 Batch 2:  loss:  1.19868
# validation accuracy:  0.5632
# Epoch 21, CIFAR-10 Batch 3:  loss:  1.13735
# validation accuracy:  0.5836
# Epoch 21, CIFAR-10 Batch 4:  loss:  1.10555
# validation accuracy:  0.5766
# Epoch 21, CIFAR-10 Batch 5:  loss:  1.14942
# validation accuracy:  0.5792
# Epoch 22, CIFAR-10 Batch 1:  loss:  1.13443
# validation accuracy:  0.588
# Epoch 22, CIFAR-10 Batch 2:  loss:  1.15199
# validation accuracy:  0.5842
# Epoch 22, CIFAR-10 Batch 3:  loss:  1.09522
# validation accuracy:  0.58
# Epoch 22, CIFAR-10 Batch 4:  loss:  1.07017
# validation accuracy:  0.59
# Epoch 22, CIFAR-10 Batch 5:  loss:  1.14526
# validation accuracy:  0.5912
# Epoch 23, CIFAR-10 Batch 1:  loss:  1.14895
# validation accuracy:  0.5936
# Epoch 23, CIFAR-10 Batch 2:  loss:  1.11902
# validation accuracy:  0.5894
# Epoch 23, CIFAR-10 Batch 3:  loss:  1.10745
# validation accuracy:  0.5806
# Epoch 23, CIFAR-10 Batch 4:  loss:  1.06753
# validation accuracy:  0.597
# Epoch 23, CIFAR-10 Batch 5:  loss:  1.11061
# validation accuracy:  0.5904
# Epoch 24, CIFAR-10 Batch 1:  loss:  1.12393
# validation accuracy:  0.5992
# Epoch 24, CIFAR-10 Batch 2:  loss:  1.13385
# validation accuracy:  0.584
# Epoch 24, CIFAR-10 Batch 3:  loss:  1.08991
# validation accuracy:  0.5798
# Epoch 24, CIFAR-10 Batch 4:  loss:  1.04397
# validation accuracy:  0.595
# Epoch 24, CIFAR-10 Batch 5:  loss:  1.09237
# validation accuracy:  0.6
# Epoch 25, CIFAR-10 Batch 1:  loss:  1.13597
# validation accuracy:  0.5814
# Epoch 25, CIFAR-10 Batch 2:  loss:  1.10843
# validation accuracy:  0.6036
# Epoch 25, CIFAR-10 Batch 3:  loss:  1.0708
# validation accuracy:  0.5892
# Epoch 25, CIFAR-10 Batch 4:  loss:  1.04121
# validation accuracy:  0.6028
# Epoch 25, CIFAR-10 Batch 5:  loss:  1.10098
# validation accuracy:  0.5962
# Epoch 26, CIFAR-10 Batch 1:  loss:  1.09035
# validation accuracy:  0.6066
# Epoch 26, CIFAR-10 Batch 2:  loss:  1.11247
# validation accuracy:  0.591
# Epoch 26, CIFAR-10 Batch 3:  loss:  1.04523
# validation accuracy:  0.6034
# Epoch 26, CIFAR-10 Batch 4:  loss:  1.02173
# validation accuracy:  0.608
# Epoch 26, CIFAR-10 Batch 5:  loss:  1.07685
# validation accuracy:  0.595
# Epoch 27, CIFAR-10 Batch 1:  loss:  1.09838
# validation accuracy:  0.609
# Epoch 27, CIFAR-10 Batch 2:  loss:  1.08253
# validation accuracy:  0.6006
# Epoch 27, CIFAR-10 Batch 3:  loss:  1.01667
# validation accuracy:  0.607
# Epoch 27, CIFAR-10 Batch 4:  loss:  1.02562
# validation accuracy:  0.6082
# Epoch 27, CIFAR-10 Batch 5:  loss:  1.07588
# validation accuracy:  0.6092
# Epoch 28, CIFAR-10 Batch 1:  loss:  1.08623
# validation accuracy:  0.606
# Epoch 28, CIFAR-10 Batch 2:  loss:  1.10526
# validation accuracy:  0.5938
# Epoch 28, CIFAR-10 Batch 3:  loss:  1.04374
# validation accuracy:  0.6014
# Epoch 28, CIFAR-10 Batch 4:  loss:  1.01879
# validation accuracy:  0.6082
# Epoch 28, CIFAR-10 Batch 5:  loss:  1.03775
# validation accuracy:  0.6058
# Epoch 29, CIFAR-10 Batch 1:  loss:  1.06235
# validation accuracy:  0.6148
# Epoch 29, CIFAR-10 Batch 2:  loss:  1.05076
# validation accuracy:  0.6156
# Epoch 29, CIFAR-10 Batch 3:  loss:  1.00659
# validation accuracy:  0.6094
# Epoch 29, CIFAR-10 Batch 4:  loss:  0.992026
# validation accuracy:  0.615
# Epoch 29, CIFAR-10 Batch 5:  loss:  1.02949
# validation accuracy:  0.6112
# Epoch 30, CIFAR-10 Batch 1:  loss:  1.04797
# validation accuracy:  0.6146
# Epoch 30, CIFAR-10 Batch 2:  loss:  1.04488
# validation accuracy:  0.6046
# Epoch 30, CIFAR-10 Batch 3:  loss:  1.01187
# validation accuracy:  0.6122
# Epoch 30, CIFAR-10 Batch 4:  loss:  0.999946
# validation accuracy:  0.6094
# Epoch 30, CIFAR-10 Batch 5:  loss:  1.02462
# validation accuracy:  0.6218
# Epoch 31, CIFAR-10 Batch 1:  loss:  1.03556
# validation accuracy:  0.6224
# Epoch 31, CIFAR-10 Batch 2:  loss:  1.01197
# validation accuracy:  0.6222
# Epoch 31, CIFAR-10 Batch 3:  loss:  0.975859
# validation accuracy:  0.6178
# Epoch 31, CIFAR-10 Batch 4:  loss:  0.995082
# validation accuracy:  0.6174
# Epoch 31, CIFAR-10 Batch 5:  loss:  0.99302
# validation accuracy:  0.6146
# Epoch 32, CIFAR-10 Batch 1:  loss:  1.03563
# validation accuracy:  0.6248
# Epoch 32, CIFAR-10 Batch 2:  loss:  1.00713
# validation accuracy:  0.626
# Epoch 32, CIFAR-10 Batch 3:  loss:  1.01022
# validation accuracy:  0.6024
# Epoch 32, CIFAR-10 Batch 4:  loss:  0.9757
# validation accuracy:  0.6236
# Epoch 32, CIFAR-10 Batch 5:  loss:  1.00101
# validation accuracy:  0.6254
# Epoch 33, CIFAR-10 Batch 1:  loss:  1.0068
# validation accuracy:  0.633
# Epoch 33, CIFAR-10 Batch 2:  loss:  0.99953
# validation accuracy:  0.6272
# Epoch 33, CIFAR-10 Batch 3:  loss:  0.960046
# validation accuracy:  0.626
# Epoch 33, CIFAR-10 Batch 4:  loss:  0.945922
# validation accuracy:  0.6316
# Epoch 33, CIFAR-10 Batch 5:  loss:  0.994392
# validation accuracy:  0.623
# Epoch 34, CIFAR-10 Batch 1:  loss:  1.01148
# validation accuracy:  0.6386
# Epoch 34, CIFAR-10 Batch 2:  loss:  0.979201
# validation accuracy:  0.6302
# Epoch 34, CIFAR-10 Batch 3:  loss:  0.973635
# validation accuracy:  0.6164
# Epoch 34, CIFAR-10 Batch 4:  loss:  0.93401
# validation accuracy:  0.6284
# Epoch 34, CIFAR-10 Batch 5:  loss:  0.968558
# validation accuracy:  0.624
# Epoch 35, CIFAR-10 Batch 1:  loss:  0.9746
# validation accuracy:  0.6322
# Epoch 35, CIFAR-10 Batch 2:  loss:  0.990402
# validation accuracy:  0.633
# Epoch 35, CIFAR-10 Batch 3:  loss:  0.939285
# validation accuracy:  0.6248
# Epoch 35, CIFAR-10 Batch 4:  loss:  0.92213
# validation accuracy:  0.636
# Epoch 35, CIFAR-10 Batch 5:  loss:  0.970374
# validation accuracy:  0.6282
# Epoch 36, CIFAR-10 Batch 1:  loss:  0.982215
# validation accuracy:  0.6432
# Epoch 36, CIFAR-10 Batch 2:  loss:  0.966043
# validation accuracy:  0.6366
# Epoch 36, CIFAR-10 Batch 3:  loss:  0.945278
# validation accuracy:  0.6276
# Epoch 36, CIFAR-10 Batch 4:  loss:  0.943284
# validation accuracy:  0.6308
# Epoch 36, CIFAR-10 Batch 5:  loss:  0.967031
# validation accuracy:  0.6256
# Epoch 37, CIFAR-10 Batch 1:  loss:  0.974423
# validation accuracy:  0.6366
# Epoch 37, CIFAR-10 Batch 2:  loss:  0.934453
# validation accuracy:  0.6388
# Epoch 37, CIFAR-10 Batch 3:  loss:  0.908395
# validation accuracy:  0.6354
# Epoch 37, CIFAR-10 Batch 4:  loss:  0.904826
# validation accuracy:  0.6334
# Epoch 37, CIFAR-10 Batch 5:  loss:  0.950762
# validation accuracy:  0.6378
# Epoch 38, CIFAR-10 Batch 1:  loss:  0.959012
# validation accuracy:  0.638
# Epoch 38, CIFAR-10 Batch 2:  loss:  0.924596
# validation accuracy:  0.6422
# Epoch 38, CIFAR-10 Batch 3:  loss:  0.920692
# validation accuracy:  0.6324
# Epoch 38, CIFAR-10 Batch 4:  loss:  0.904799
# validation accuracy:  0.6408
# Epoch 38, CIFAR-10 Batch 5:  loss:  0.926664
# validation accuracy:  0.641
# Epoch 39, CIFAR-10 Batch 1:  loss:  0.948735
# validation accuracy:  0.6472
# Epoch 39, CIFAR-10 Batch 2:  loss:  0.917456
# validation accuracy:  0.638
# Epoch 39, CIFAR-10 Batch 3:  loss:  0.918645
# validation accuracy:  0.6358
# Epoch 39, CIFAR-10 Batch 4:  loss:  0.912882
# validation accuracy:  0.638
# Epoch 39, CIFAR-10 Batch 5:  loss:  0.926255
# validation accuracy:  0.6402
# Epoch 40, CIFAR-10 Batch 1:  loss:  0.937105
# validation accuracy:  0.6416
# Epoch 40, CIFAR-10 Batch 2:  loss:  0.928083
# validation accuracy:  0.6438
# Epoch 40, CIFAR-10 Batch 3:  loss:  0.893886
# validation accuracy:  0.6396
# Epoch 40, CIFAR-10 Batch 4:  loss:  0.885419
# validation accuracy:  0.647
# Epoch 40, CIFAR-10 Batch 5:  loss:  0.908617
# validation accuracy:  0.6402
# Epoch 41, CIFAR-10 Batch 1:  loss:  0.909961
# validation accuracy:  0.6474
# Epoch 41, CIFAR-10 Batch 2:  loss:  0.900041
# validation accuracy:  0.6526
# Epoch 41, CIFAR-10 Batch 3:  loss:  0.9056
# validation accuracy:  0.632
# Epoch 41, CIFAR-10 Batch 4:  loss:  0.862149
# validation accuracy:  0.6476
# Epoch 41, CIFAR-10 Batch 5:  loss:  0.875055
# validation accuracy:  0.6506
# Epoch 42, CIFAR-10 Batch 1:  loss:  0.913594
# validation accuracy:  0.6466
# Epoch 42, CIFAR-10 Batch 2:  loss:  0.882797
# validation accuracy:  0.6508
# Epoch 42, CIFAR-10 Batch 3:  loss:  0.881108
# validation accuracy:  0.641
# Epoch 42, CIFAR-10 Batch 4:  loss:  0.873807
# validation accuracy:  0.6456
# Epoch 42, CIFAR-10 Batch 5:  loss:  0.887131
# validation accuracy:  0.6512
# Epoch 43, CIFAR-10 Batch 1:  loss:  0.915347
# validation accuracy:  0.6418
# Epoch 43, CIFAR-10 Batch 2:  loss:  0.898288
# validation accuracy:  0.6534
# Epoch 43, CIFAR-10 Batch 3:  loss:  0.884478
# validation accuracy:  0.6406
# Epoch 43, CIFAR-10 Batch 4:  loss:  0.870043
# validation accuracy:  0.6538
# Epoch 43, CIFAR-10 Batch 5:  loss:  0.890101
# validation accuracy:  0.6464
# Epoch 44, CIFAR-10 Batch 1:  loss:  0.897653
# validation accuracy:  0.648
# Epoch 44, CIFAR-10 Batch 2:  loss:  0.892918
# validation accuracy:  0.6468
# Epoch 44, CIFAR-10 Batch 3:  loss:  0.868663
# validation accuracy:  0.649
# Epoch 44, CIFAR-10 Batch 4:  loss:  0.859071
# validation accuracy:  0.651
# Epoch 44, CIFAR-10 Batch 5:  loss:  0.860979
# validation accuracy:  0.656
# Epoch 45, CIFAR-10 Batch 1:  loss:  0.887438
# validation accuracy:  0.6612
# Epoch 45, CIFAR-10 Batch 2:  loss:  0.876276
# validation accuracy:  0.6506
# Epoch 45, CIFAR-10 Batch 3:  loss:  0.850476
# validation accuracy:  0.6556
# Epoch 45, CIFAR-10 Batch 4:  loss:  0.860319
# validation accuracy:  0.6572
# Epoch 45, CIFAR-10 Batch 5:  loss:  0.876451
# validation accuracy:  0.6472
# Epoch 46, CIFAR-10 Batch 1:  loss:  0.875671
# validation accuracy:  0.6532
# Epoch 46, CIFAR-10 Batch 2:  loss:  0.863303
# validation accuracy:  0.6522
# Epoch 46, CIFAR-10 Batch 3:  loss:  0.857247
# validation accuracy:  0.6488
# Epoch 46, CIFAR-10 Batch 4:  loss:  0.836748
# validation accuracy:  0.6544
# Epoch 46, CIFAR-10 Batch 5:  loss:  0.848857
# validation accuracy:  0.6522
# Epoch 47, CIFAR-10 Batch 1:  loss:  0.877961
# validation accuracy:  0.6592
# Epoch 47, CIFAR-10 Batch 2:  loss:  0.868616
# validation accuracy:  0.6584
# Epoch 47, CIFAR-10 Batch 3:  loss:  0.843782
# validation accuracy:  0.6514
# Epoch 47, CIFAR-10 Batch 4:  loss:  0.841903
# validation accuracy:  0.6528
# Epoch 47, CIFAR-10 Batch 5:  loss:  0.835371
# validation accuracy:  0.6532
# Epoch 48, CIFAR-10 Batch 1:  loss:  0.878813
# validation accuracy:  0.6588
# Epoch 48, CIFAR-10 Batch 2:  loss:  0.849361
# validation accuracy:  0.655
# Epoch 48, CIFAR-10 Batch 3:  loss:  0.861567
# validation accuracy:  0.6532
# Epoch 48, CIFAR-10 Batch 4:  loss:  0.82247
# validation accuracy:  0.6526
# Epoch 48, CIFAR-10 Batch 5:  loss:  0.841338
# validation accuracy:  0.6538
# Epoch 49, CIFAR-10 Batch 1:  loss:  0.86491
# validation accuracy:  0.6656
# Epoch 49, CIFAR-10 Batch 2:  loss:  0.847104
# validation accuracy:  0.664
# Epoch 49, CIFAR-10 Batch 3:  loss:  0.84311
# validation accuracy:  0.6626
# Epoch 49, CIFAR-10 Batch 4:  loss:  0.82439
# validation accuracy:  0.662
# Epoch 49, CIFAR-10 Batch 5:  loss:  0.830593
# validation accuracy:  0.6604
# Epoch 50, CIFAR-10 Batch 1:  loss:  0.859846
# validation accuracy:  0.6592
# Epoch 50, CIFAR-10 Batch 2:  loss:  0.842079
# validation accuracy:  0.67
# Epoch 50, CIFAR-10 Batch 3:  loss:  0.832382
# validation accuracy:  0.6496
# Epoch 50, CIFAR-10 Batch 4:  loss:  0.808873
# validation accuracy:  0.6624
# Epoch 50, CIFAR-10 Batch 5:  loss:  0.828982
# validation accuracy:  0.6598
# Epoch 51, CIFAR-10 Batch 1:  loss:  0.835015
# validation accuracy:  0.6624
# Epoch 51, CIFAR-10 Batch 2:  loss:  0.84509
# validation accuracy:  0.665
# Epoch 51, CIFAR-10 Batch 3:  loss:  0.837771
# validation accuracy:  0.6496
# Epoch 51, CIFAR-10 Batch 4:  loss:  0.810043
# validation accuracy:  0.6624
# Epoch 51, CIFAR-10 Batch 5:  loss:  0.813972
# validation accuracy:  0.6646
# Epoch 52, CIFAR-10 Batch 1:  loss:  0.848343
# validation accuracy:  0.6642
# Epoch 52, CIFAR-10 Batch 2:  loss:  0.846921
# validation accuracy:  0.6572
# Epoch 52, CIFAR-10 Batch 3:  loss:  0.816218
# validation accuracy:  0.6586
# Epoch 52, CIFAR-10 Batch 4:  loss:  0.811889
# validation accuracy:  0.6616
# Epoch 52, CIFAR-10 Batch 5:  loss:  0.818339
# validation accuracy:  0.666
# Epoch 53, CIFAR-10 Batch 1:  loss:  0.831149
# validation accuracy:  0.6642
# Epoch 53, CIFAR-10 Batch 2:  loss:  0.839172
# validation accuracy:  0.6622
# Epoch 53, CIFAR-10 Batch 3:  loss:  0.797588
# validation accuracy:  0.6596
# Epoch 53, CIFAR-10 Batch 4:  loss:  0.816352
# validation accuracy:  0.6574
# Epoch 53, CIFAR-10 Batch 5:  loss:  0.807223
# validation accuracy:  0.6688
# Epoch 54, CIFAR-10 Batch 1:  loss:  0.809577
# validation accuracy:  0.6652
# Epoch 54, CIFAR-10 Batch 2:  loss:  0.820696
# validation accuracy:  0.6606
# Epoch 54, CIFAR-10 Batch 3:  loss:  0.829115
# validation accuracy:  0.659
# Epoch 54, CIFAR-10 Batch 4:  loss:  0.774099
# validation accuracy:  0.669
# Epoch 54, CIFAR-10 Batch 5:  loss:  0.8163
# validation accuracy:  0.6636
# Epoch 55, CIFAR-10 Batch 1:  loss:  0.82951
# validation accuracy:  0.6612
# Epoch 55, CIFAR-10 Batch 2:  loss:  0.806094
# validation accuracy:  0.6664
# Epoch 55, CIFAR-10 Batch 3:  loss:  0.81478
# validation accuracy:  0.6552
# Epoch 55, CIFAR-10 Batch 4:  loss:  0.771864
# validation accuracy:  0.6676
# Epoch 55, CIFAR-10 Batch 5:  loss:  0.806848
# validation accuracy:  0.6696
# Epoch 56, CIFAR-10 Batch 1:  loss:  0.804715
# validation accuracy:  0.6666
# Epoch 56, CIFAR-10 Batch 2:  loss:  0.802943
# validation accuracy:  0.6734
# Epoch 56, CIFAR-10 Batch 3:  loss:  0.80674
# validation accuracy:  0.6578
# Epoch 56, CIFAR-10 Batch 4:  loss:  0.780844
# validation accuracy:  0.6708
# Epoch 56, CIFAR-10 Batch 5:  loss:  0.805679
# validation accuracy:  0.664
# Epoch 57, CIFAR-10 Batch 1:  loss:  0.799256
# validation accuracy:  0.673
# Epoch 57, CIFAR-10 Batch 2:  loss:  0.796381
# validation accuracy:  0.672
# Epoch 57, CIFAR-10 Batch 3:  loss:  0.784348
# validation accuracy:  0.665
# Epoch 57, CIFAR-10 Batch 4:  loss:  0.773299
# validation accuracy:  0.6728
# Epoch 57, CIFAR-10 Batch 5:  loss:  0.790391
# validation accuracy:  0.6668
# Epoch 58, CIFAR-10 Batch 1:  loss:  0.803732
# validation accuracy:  0.6596
# Epoch 58, CIFAR-10 Batch 2:  loss:  0.783887
# validation accuracy:  0.6728
# Epoch 58, CIFAR-10 Batch 3:  loss:  0.774208
# validation accuracy:  0.6642
# Epoch 58, CIFAR-10 Batch 4:  loss:  0.758131
# validation accuracy:  0.6726
# Epoch 58, CIFAR-10 Batch 5:  loss:  0.755767
# validation accuracy:  0.677
# Epoch 59, CIFAR-10 Batch 1:  loss:  0.802801
# validation accuracy:  0.6646
# Epoch 59, CIFAR-10 Batch 2:  loss:  0.793909
# validation accuracy:  0.6696
# Epoch 59, CIFAR-10 Batch 3:  loss:  0.805171
# validation accuracy:  0.6706
# Epoch 59, CIFAR-10 Batch 4:  loss:  0.752038
# validation accuracy:  0.6696
# Epoch 59, CIFAR-10 Batch 5:  loss:  0.743517
# validation accuracy:  0.673
# Epoch 60, CIFAR-10 Batch 1:  loss:  0.79266
# validation accuracy:  0.6698
# Epoch 60, CIFAR-10 Batch 2:  loss:  0.798114
# validation accuracy:  0.6642
# Epoch 60, CIFAR-10 Batch 3:  loss:  0.773043
# validation accuracy:  0.67
# Epoch 60, CIFAR-10 Batch 4:  loss:  0.73364
# validation accuracy:  0.6772
# Epoch 60, CIFAR-10 Batch 5:  loss:  0.734846
# validation accuracy:  0.6768
# Epoch 61, CIFAR-10 Batch 1:  loss:  0.764142
# validation accuracy:  0.6686
# Epoch 61, CIFAR-10 Batch 2:  loss:  0.771809
# validation accuracy:  0.6742
# Epoch 61, CIFAR-10 Batch 3:  loss:  0.777274
# validation accuracy:  0.6658
# Epoch 61, CIFAR-10 Batch 4:  loss:  0.745064
# validation accuracy:  0.6748
# Epoch 61, CIFAR-10 Batch 5:  loss:  0.753573
# validation accuracy:  0.6728
# Epoch 62, CIFAR-10 Batch 1:  loss:  0.793184
# validation accuracy:  0.6708
# Epoch 62, CIFAR-10 Batch 2:  loss:  0.772413
# validation accuracy:  0.679
# Epoch 62, CIFAR-10 Batch 3:  loss:  0.757877
# validation accuracy:  0.6764
# Epoch 62, CIFAR-10 Batch 4:  loss:  0.733455
# validation accuracy:  0.6788
# Epoch 62, CIFAR-10 Batch 5:  loss:  0.759397
# validation accuracy:  0.6758
# Epoch 63, CIFAR-10 Batch 1:  loss:  0.787232
# validation accuracy:  0.668
# Epoch 63, CIFAR-10 Batch 2:  loss:  0.775361
# validation accuracy:  0.6792
# Epoch 63, CIFAR-10 Batch 3:  loss:  0.763982
# validation accuracy:  0.6608
# Epoch 63, CIFAR-10 Batch 4:  loss:  0.711342
# validation accuracy:  0.6798
# Epoch 63, CIFAR-10 Batch 5:  loss:  0.749595
# validation accuracy:  0.6792
# Epoch 64, CIFAR-10 Batch 1:  loss:  0.772315
# validation accuracy:  0.6796
# Epoch 64, CIFAR-10 Batch 2:  loss:  0.759843
# validation accuracy:  0.6764
# Epoch 64, CIFAR-10 Batch 3:  loss:  0.759581
# validation accuracy:  0.6704
# Epoch 64, CIFAR-10 Batch 4:  loss:  0.741211
# validation accuracy:  0.6746
# Epoch 64, CIFAR-10 Batch 5:  loss:  0.769174
# validation accuracy:  0.6748
# Epoch 65, CIFAR-10 Batch 1:  loss:  0.753691
# validation accuracy:  0.6802
# Epoch 65, CIFAR-10 Batch 2:  loss:  0.749467
# validation accuracy:  0.6802
# Epoch 65, CIFAR-10 Batch 3:  loss:  0.767576
# validation accuracy:  0.6688
# Epoch 65, CIFAR-10 Batch 4:  loss:  0.730149
# validation accuracy:  0.6774
# Epoch 65, CIFAR-10 Batch 5:  loss:  0.712977
# validation accuracy:  0.6814
# Epoch 66, CIFAR-10 Batch 1:  loss:  0.751304
# validation accuracy:  0.6764
# Epoch 66, CIFAR-10 Batch 2:  loss:  0.745564
# validation accuracy:  0.6762
# Epoch 66, CIFAR-10 Batch 3:  loss:  0.76049
# validation accuracy:  0.6714
# Epoch 66, CIFAR-10 Batch 4:  loss:  0.72201
# validation accuracy:  0.6788
# Epoch 66, CIFAR-10 Batch 5:  loss:  0.753336
# validation accuracy:  0.674
# Epoch 67, CIFAR-10 Batch 1:  loss:  0.787538
# validation accuracy:  0.6748
# Epoch 67, CIFAR-10 Batch 2:  loss:  0.766914
# validation accuracy:  0.6728
# Epoch 67, CIFAR-10 Batch 3:  loss:  0.733445
# validation accuracy:  0.6778
# Epoch 67, CIFAR-10 Batch 4:  loss:  0.713044
# validation accuracy:  0.6794
# Epoch 67, CIFAR-10 Batch 5:  loss:  0.726016
# validation accuracy:  0.6848
# Epoch 68, CIFAR-10 Batch 1:  loss:  0.740223
# validation accuracy:  0.6788
# Epoch 68, CIFAR-10 Batch 2:  loss:  0.746975
# validation accuracy:  0.6844
# Epoch 68, CIFAR-10 Batch 3:  loss:  0.746833
# validation accuracy:  0.6746
# Epoch 68, CIFAR-10 Batch 4:  loss:  0.70683
# validation accuracy:  0.6766
# Epoch 68, CIFAR-10 Batch 5:  loss:  0.719792
# validation accuracy:  0.6794
# Epoch 69, CIFAR-10 Batch 1:  loss:  0.778144
# validation accuracy:  0.6782
# Epoch 69, CIFAR-10 Batch 2:  loss:  0.761581
# validation accuracy:  0.6788
# Epoch 69, CIFAR-10 Batch 3:  loss:  0.730139
# validation accuracy:  0.6728
# Epoch 69, CIFAR-10 Batch 4:  loss:  0.699138
# validation accuracy:  0.6834
# Epoch 69, CIFAR-10 Batch 5:  loss:  0.69296
# validation accuracy:  0.6794
# Epoch 70, CIFAR-10 Batch 1:  loss:  0.730954
# validation accuracy:  0.68
# Epoch 70, CIFAR-10 Batch 2:  loss:  0.742095
# validation accuracy:  0.6884
# Epoch 70, CIFAR-10 Batch 3:  loss:  0.711568
# validation accuracy:  0.6808
# Epoch 70, CIFAR-10 Batch 4:  loss:  0.690853
# validation accuracy:  0.6836
# Epoch 70, CIFAR-10 Batch 5:  loss:  0.746672
# validation accuracy:  0.675
# Epoch 71, CIFAR-10 Batch 1:  loss:  0.728714
# validation accuracy:  0.6894
# Epoch 71, CIFAR-10 Batch 2:  loss:  0.71925
# validation accuracy:  0.6894
# Epoch 71, CIFAR-10 Batch 3:  loss:  0.723261
# validation accuracy:  0.675
# Epoch 71, CIFAR-10 Batch 4:  loss:  0.701196
# validation accuracy:  0.6822
# Epoch 71, CIFAR-10 Batch 5:  loss:  0.719659
# validation accuracy:  0.6798
# Epoch 72, CIFAR-10 Batch 1:  loss:  0.746284
# validation accuracy:  0.6754
# Epoch 72, CIFAR-10 Batch 2:  loss:  0.724778
# validation accuracy:  0.6896
# Epoch 72, CIFAR-10 Batch 3:  loss:  0.716078
# validation accuracy:  0.6838
# Epoch 72, CIFAR-10 Batch 4:  loss:  0.694532
# validation accuracy:  0.6796
# Epoch 72, CIFAR-10 Batch 5:  loss:  0.696668
# validation accuracy:  0.683
# Epoch 73, CIFAR-10 Batch 1:  loss:  0.716505
# validation accuracy:  0.6898
# Epoch 73, CIFAR-10 Batch 2:  loss:  0.734547
# validation accuracy:  0.6734
# Epoch 73, CIFAR-10 Batch 3:  loss:  0.731425
# validation accuracy:  0.677
# Epoch 73, CIFAR-10 Batch 4:  loss:  0.686912
# validation accuracy:  0.691
# Epoch 73, CIFAR-10 Batch 5:  loss:  0.692616
# validation accuracy:  0.6902
# Epoch 74, CIFAR-10 Batch 1:  loss:  0.740795
# validation accuracy:  0.679
# Epoch 74, CIFAR-10 Batch 2:  loss:  0.729606
# validation accuracy:  0.6826
# Epoch 74, CIFAR-10 Batch 3:  loss:  0.708868
# validation accuracy:  0.686
# Epoch 74, CIFAR-10 Batch 4:  loss:  0.675905
# validation accuracy:  0.6928
# Epoch 74, CIFAR-10 Batch 5:  loss:  0.690349
# validation accuracy:  0.6852
# Epoch 75, CIFAR-10 Batch 1:  loss:  0.696985
# validation accuracy:  0.6828
# Epoch 75, CIFAR-10 Batch 2:  loss:  0.7042
# validation accuracy:  0.6856
# Epoch 75, CIFAR-10 Batch 3:  loss:  0.697964
# validation accuracy:  0.6826
# Epoch 75, CIFAR-10 Batch 4:  loss:  0.667492
# validation accuracy:  0.6928
# Epoch 75, CIFAR-10 Batch 5:  loss:  0.674462
# validation accuracy:  0.6878
# Epoch 76, CIFAR-10 Batch 1:  loss:  0.697438
# validation accuracy:  0.6918
# Epoch 76, CIFAR-10 Batch 2:  loss:  0.692676
# validation accuracy:  0.6868
# Epoch 76, CIFAR-10 Batch 3:  loss:  0.69169
# validation accuracy:  0.6888
# Epoch 76, CIFAR-10 Batch 4:  loss:  0.664905
# validation accuracy:  0.6936
# Epoch 76, CIFAR-10 Batch 5:  loss:  0.668063
# validation accuracy:  0.6878
# Epoch 77, CIFAR-10 Batch 1:  loss:  0.697236
# validation accuracy:  0.6902
# Epoch 77, CIFAR-10 Batch 2:  loss:  0.722354
# validation accuracy:  0.6834
# Epoch 77, CIFAR-10 Batch 3:  loss:  0.712771
# validation accuracy:  0.6856
# Epoch 77, CIFAR-10 Batch 4:  loss:  0.673597
# validation accuracy:  0.6918
# Epoch 77, CIFAR-10 Batch 5:  loss:  0.67897
# validation accuracy:  0.6868
# Epoch 78, CIFAR-10 Batch 1:  loss:  0.688579
# validation accuracy:  0.6912
# Epoch 78, CIFAR-10 Batch 2:  loss:  0.689835
# validation accuracy:  0.6934
# Epoch 78, CIFAR-10 Batch 3:  loss:  0.691298
# validation accuracy:  0.6866
# Epoch 78, CIFAR-10 Batch 4:  loss:  0.655917
# validation accuracy:  0.6952
# Epoch 78, CIFAR-10 Batch 5:  loss:  0.67186
# validation accuracy:  0.6878
# Epoch 79, CIFAR-10 Batch 1:  loss:  0.6804
# validation accuracy:  0.6926
# Epoch 79, CIFAR-10 Batch 2:  loss:  0.679
# validation accuracy:  0.688
# Epoch 79, CIFAR-10 Batch 3:  loss:  0.716446
# validation accuracy:  0.6736
# Epoch 79, CIFAR-10 Batch 4:  loss:  0.663922
# validation accuracy:  0.6938
# Epoch 79, CIFAR-10 Batch 5:  loss:  0.700454
# validation accuracy:  0.6802
# Epoch 80, CIFAR-10 Batch 1:  loss:  0.67175
# validation accuracy:  0.6946
# Epoch 80, CIFAR-10 Batch 2:  loss:  0.689014
# validation accuracy:  0.6902
# Epoch 80, CIFAR-10 Batch 3:  loss:  0.694219
# validation accuracy:  0.6804
# Epoch 80, CIFAR-10 Batch 4:  loss:  0.661844
# validation accuracy:  0.6888
# Epoch 80, CIFAR-10 Batch 5:  loss:  0.655792
# validation accuracy:  0.6918
# Epoch 81, CIFAR-10 Batch 1:  loss:  0.66839
# validation accuracy:  0.6954
# Epoch 81, CIFAR-10 Batch 2:  loss:  0.688821
# validation accuracy:  0.6876
# Epoch 81, CIFAR-10 Batch 3:  loss:  0.695468
# validation accuracy:  0.68
# Epoch 81, CIFAR-10 Batch 4:  loss:  0.662315
# validation accuracy:  0.699
# Epoch 81, CIFAR-10 Batch 5:  loss:  0.684669
# validation accuracy:  0.6766
# Epoch 82, CIFAR-10 Batch 1:  loss:  0.659583
# validation accuracy:  0.6938
# Epoch 82, CIFAR-10 Batch 2:  loss:  0.681658
# validation accuracy:  0.6958
# Epoch 82, CIFAR-10 Batch 3:  loss:  0.673126
# validation accuracy:  0.6842
# Epoch 82, CIFAR-10 Batch 4:  loss:  0.650184
# validation accuracy:  0.6946
# Epoch 82, CIFAR-10 Batch 5:  loss:  0.649849
# validation accuracy:  0.6912
# Epoch 83, CIFAR-10 Batch 1:  loss:  0.657443
# validation accuracy:  0.6974
# Epoch 83, CIFAR-10 Batch 2:  loss:  0.675889
# validation accuracy:  0.6846
# Epoch 83, CIFAR-10 Batch 3:  loss:  0.706889
# validation accuracy:  0.6764
# Epoch 83, CIFAR-10 Batch 4:  loss:  0.648285
# validation accuracy:  0.6896
# Epoch 83, CIFAR-10 Batch 5:  loss:  0.686526
# validation accuracy:  0.685
# Epoch 84, CIFAR-10 Batch 1:  loss:  0.654553
# validation accuracy:  0.6986
# Epoch 84, CIFAR-10 Batch 2:  loss:  0.661252
# validation accuracy:  0.6896
# Epoch 84, CIFAR-10 Batch 3:  loss:  0.644656
# validation accuracy:  0.6874
# Epoch 84, CIFAR-10 Batch 4:  loss:  0.631948
# validation accuracy:  0.7038
# Epoch 84, CIFAR-10 Batch 5:  loss:  0.667236
# validation accuracy:  0.693
# Epoch 85, CIFAR-10 Batch 1:  loss:  0.64413
# validation accuracy:  0.6938
# Epoch 85, CIFAR-10 Batch 2:  loss:  0.693874
# validation accuracy:  0.6834
# Epoch 85, CIFAR-10 Batch 3:  loss:  0.67443
# validation accuracy:  0.678
# Epoch 85, CIFAR-10 Batch 4:  loss:  0.631066
# validation accuracy:  0.6964
# Epoch 85, CIFAR-10 Batch 5:  loss:  0.659654
# validation accuracy:  0.6854
# Epoch 86, CIFAR-10 Batch 1:  loss:  0.662008
# validation accuracy:  0.6932
# Epoch 86, CIFAR-10 Batch 2:  loss:  0.68306
# validation accuracy:  0.692
# Epoch 86, CIFAR-10 Batch 3:  loss:  0.661226
# validation accuracy:  0.6938
# Epoch 86, CIFAR-10 Batch 4:  loss:  0.638375
# validation accuracy:  0.6964
# Epoch 86, CIFAR-10 Batch 5:  loss:  0.645396
# validation accuracy:  0.6868
# Epoch 87, CIFAR-10 Batch 1:  loss:  0.6355
# validation accuracy:  0.6964
# Epoch 87, CIFAR-10 Batch 2:  loss:  0.665854
# validation accuracy:  0.687
# Epoch 87, CIFAR-10 Batch 3:  loss:  0.671319
# validation accuracy:  0.6794
# Epoch 87, CIFAR-10 Batch 4:  loss:  0.638609
# validation accuracy:  0.6912
# Epoch 87, CIFAR-10 Batch 5:  loss:  0.649045
# validation accuracy:  0.687
# Epoch 88, CIFAR-10 Batch 1:  loss:  0.64352
# validation accuracy:  0.6954
# Epoch 88, CIFAR-10 Batch 2:  loss:  0.640983
# validation accuracy:  0.7004
# Epoch 88, CIFAR-10 Batch 3:  loss:  0.643972
# validation accuracy:  0.692
# Epoch 88, CIFAR-10 Batch 4:  loss:  0.632657
# validation accuracy:  0.6906
# Epoch 88, CIFAR-10 Batch 5:  loss:  0.659085
# validation accuracy:  0.6932
# Epoch 89, CIFAR-10 Batch 1:  loss:  0.638123
# validation accuracy:  0.6934
# Epoch 89, CIFAR-10 Batch 2:  loss:  0.646103
# validation accuracy:  0.6962
# Epoch 89, CIFAR-10 Batch 3:  loss:  0.66175
# validation accuracy:  0.6888
# Epoch 89, CIFAR-10 Batch 4:  loss:  0.627955
# validation accuracy:  0.6964
# Epoch 89, CIFAR-10 Batch 5:  loss:  0.624458
# validation accuracy:  0.6936
# Epoch 90, CIFAR-10 Batch 1:  loss:  0.648492
# validation accuracy:  0.697
# Epoch 90, CIFAR-10 Batch 2:  loss:  0.656423
# validation accuracy:  0.691
# Epoch 90, CIFAR-10 Batch 3:  loss:  0.661833
# validation accuracy:  0.696
# Epoch 90, CIFAR-10 Batch 4:  loss:  0.61074
# validation accuracy:  0.6988
# Epoch 90, CIFAR-10 Batch 5:  loss:  0.625546
# validation accuracy:  0.6962
# Epoch 91, CIFAR-10 Batch 1:  loss:  0.623472
# validation accuracy:  0.7028
# Epoch 91, CIFAR-10 Batch 2:  loss:  0.638528
# validation accuracy:  0.6964
# Epoch 91, CIFAR-10 Batch 3:  loss:  0.641472
# validation accuracy:  0.6922
# Epoch 91, CIFAR-10 Batch 4:  loss:  0.606238
# validation accuracy:  0.698
# Epoch 91, CIFAR-10 Batch 5:  loss:  0.616525
# validation accuracy:  0.6972
# Epoch 92, CIFAR-10 Batch 1:  loss:  0.642651
# validation accuracy:  0.693
# Epoch 92, CIFAR-10 Batch 2:  loss:  0.641779
# validation accuracy:  0.6902
# Epoch 92, CIFAR-10 Batch 3:  loss:  0.651344
# validation accuracy:  0.6836
# Epoch 92, CIFAR-10 Batch 4:  loss:  0.614059
# validation accuracy:  0.697
# Epoch 92, CIFAR-10 Batch 5:  loss:  0.610306
# validation accuracy:  0.696
# Epoch 93, CIFAR-10 Batch 1:  loss:  0.628394
# validation accuracy:  0.7014
# Epoch 93, CIFAR-10 Batch 2:  loss:  0.652032
# validation accuracy:  0.6954
# Epoch 93, CIFAR-10 Batch 3:  loss:  0.654367
# validation accuracy:  0.6964
# Epoch 93, CIFAR-10 Batch 4:  loss:  0.637577
# validation accuracy:  0.695
# Epoch 93, CIFAR-10 Batch 5:  loss:  0.626457
# validation accuracy:  0.6952
# Epoch 94, CIFAR-10 Batch 1:  loss:  0.614177
# validation accuracy:  0.7022
# Epoch 94, CIFAR-10 Batch 2:  loss:  0.618522
# validation accuracy:  0.6984
# Epoch 94, CIFAR-10 Batch 3:  loss:  0.636512
# validation accuracy:  0.6866
# Epoch 94, CIFAR-10 Batch 4:  loss:  0.622799
# validation accuracy:  0.698
# Epoch 94, CIFAR-10 Batch 5:  loss:  0.611968
# validation accuracy:  0.6936
# Epoch 95, CIFAR-10 Batch 1:  loss:  0.631203
# validation accuracy:  0.6958
# Epoch 95, CIFAR-10 Batch 2:  loss:  0.623246
# validation accuracy:  0.6914
# Epoch 95, CIFAR-10 Batch 3:  loss:  0.63883
# validation accuracy:  0.6904
# Epoch 95, CIFAR-10 Batch 4:  loss:  0.601265
# validation accuracy:  0.6956
# Epoch 95, CIFAR-10 Batch 5:  loss:  0.604228
# validation accuracy:  0.6922
# Epoch 96, CIFAR-10 Batch 1:  loss:  0.611207
# validation accuracy:  0.692
# Epoch 96, CIFAR-10 Batch 2:  loss:  0.621761
# validation accuracy:  0.6964
# Epoch 96, CIFAR-10 Batch 3:  loss:  0.611318
# validation accuracy:  0.6974
# Epoch 96, CIFAR-10 Batch 4:  loss:  0.587128
# validation accuracy:  0.6998
# Epoch 96, CIFAR-10 Batch 5:  loss:  0.591958
# validation accuracy:  0.7024
# Epoch 97, CIFAR-10 Batch 1:  loss:  0.607947
# validation accuracy:  0.7024
# Epoch 97, CIFAR-10 Batch 2:  loss:  0.617308
# validation accuracy:  0.701
# Epoch 97, CIFAR-10 Batch 3:  loss:  0.615152
# validation accuracy:  0.6958
# Epoch 97, CIFAR-10 Batch 4:  loss:  0.580329
# validation accuracy:  0.6994
# Epoch 97, CIFAR-10 Batch 5:  loss:  0.600109
# validation accuracy:  0.6916
# Epoch 98, CIFAR-10 Batch 1:  loss:  0.62712
# validation accuracy:  0.689
# Epoch 98, CIFAR-10 Batch 2:  loss:  0.611924
# validation accuracy:  0.7032
# Epoch 98, CIFAR-10 Batch 3:  loss:  0.620186
# validation accuracy:  0.7002
# Epoch 98, CIFAR-10 Batch 4:  loss:  0.586704
# validation accuracy:  0.6982
# Epoch 98, CIFAR-10 Batch 5:  loss:  0.588714
# validation accuracy:  0.6992
# Epoch 99, CIFAR-10 Batch 1:  loss:  0.616433
# validation accuracy:  0.7
# Epoch 99, CIFAR-10 Batch 2:  loss:  0.626803
# validation accuracy:  0.6862
# Epoch 99, CIFAR-10 Batch 3:  loss:  0.637165
# validation accuracy:  0.6862
# Epoch 99, CIFAR-10 Batch 4:  loss:  0.567461
# validation accuracy:  0.7084
# Epoch 99, CIFAR-10 Batch 5:  loss:  0.578941
# validation accuracy:  0.7022
# Epoch 100, CIFAR-10 Batch 1:  loss:  0.594524
# validation accuracy:  0.6992
# Epoch 100, CIFAR-10 Batch 2:  loss:  0.586652
# validation accuracy:  0.7006
# Epoch 100, CIFAR-10 Batch 3:  loss:  0.602146
# validation accuracy:  0.6966
# Epoch 100, CIFAR-10 Batch 4:  loss:  0.597253
# validation accuracy:  0.6996
# Epoch 100, CIFAR-10 Batch 5:  loss:  0.590771
# validation accuracy:  0.6996

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6923999905586242

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
